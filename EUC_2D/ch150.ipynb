# %% [markdown]
# ch150_NNHonly

# %%
import re
import numpy as np
import matplotlib.pyplot as plt

class TSPSolver:
    def __init__(self, points):
        self.points = np.array(points)
        self.n = len(points)
        self.tour = None

    def nearest_neighbor(self, start=None):
        if start is None:
            start = np.random.randint(0, self.n)
        unvisited = set(range(self.n))
        unvisited.remove(start)
        tour = [start]

        while unvisited:
            current_city = tour[-1]
            nearest_city = min(unvisited, key=lambda city: np.linalg.norm(self.points[current_city] - self.points[city]))
            tour.append(nearest_city)
            unvisited.remove(nearest_city)

        self.tour = tour

    def total_distance(self, tour=None):
        if tour is None:
            tour = self.tour
        return sum(np.linalg.norm(self.points[tour[i]] - self.points[tour[i + 1]]) for i in range(self.n - 1))

    def solve(self):
        self.nearest_neighbor()
        # Connect the last city back to the starting city to form a closed tour
        self.tour.append(self.tour[0])

# Parse the TSP dataset and extract coordinates
def parse_tsp_dataset(data):
    coordinates = []
    pattern = re.compile(r'(\d+)\s+([\d.]+)\s+([\d.]+)')

    in_node_coord_section = False
    for line in data.split('\n'):
        if line.startswith("NODE_COORD_SECTION"):
            in_node_coord_section = True
            continue
        if line.startswith("EOF"):
            break
        if in_node_coord_section:
            match = pattern.match(line)
            if match:
                coordinates.append((float(match.group(2)), float(match.group(3))))

    return coordinates

# Load the TSP dataset from a file
def load_tsp_file(file_path):
    with open(file_path, 'r') as file:
        tsp_data = file.read()
    return tsp_data

# Specify the path to your TSP file
tsp_file_path = "ch150.tsp"

# Load the TSP dataset from the file
tsp_data = load_tsp_file(tsp_file_path)

# Parse the dataset and extract coordinates
city_coordinates = parse_tsp_dataset(tsp_data)

# Create TSPSolver instance and solve using nearest neighbor
total_distances = []
for i in range(10):
    solver = TSPSolver(city_coordinates)
    solver.solve()
    total_distance = solver.total_distance()
    total_distances.append(total_distance)
    # Plot the solution
    plt.figure()
    plt.scatter(solver.points[:, 0], solver.points[:, 1])
    tour_points = np.array([solver.points[i] for i in solver.tour])
    plt.plot(tour_points[:, 0], tour_points[:, 1], 'r-')
    plt.title(f'TSP Solution using Nearest Neighbor (Total Distance: {total_distance:.2f})')
    plt.show()

# Calculate average tour length
average_tour_length = np.mean(total_distances)
print("Average Tour Length:", average_tour_length)
# Out:
# Average Tour Length: 7337.459796387955

# %% [markdown]
# ch150_NNHwith2OPT

# %%
import re
import numpy as np
import matplotlib.pyplot as plt

class TSPSolver:
    def __init__(self, points):
        self.points = np.array(points)
        self.n = len(points)
        self.tour = None

    def nearest_neighbor(self, start=None):
        if start is None:
            start = np.random.randint(0, self.n)
        unvisited = set(range(self.n))
        unvisited.remove(start)
        tour = [start]

        while unvisited:
            current_city = tour[-1]
            nearest_city = min(unvisited, key=lambda city: np.linalg.norm(self.points[current_city] - self.points[city]))
            tour.append(nearest_city)
            unvisited.remove(nearest_city)

        self.tour = tour

    def total_distance(self, tour=None):
        if tour is None:
            tour = self.tour
        return sum(np.linalg.norm(self.points[tour[i]] - self.points[tour[i + 1]]) for i in range(self.n - 1))

    def two_opt_swap(self, tour, i, k):
        new_tour = tour[:i] + tour[i:k + 1][::-1] + tour[k + 1:]
        return new_tour

    def two_opt(self, tour=None):
        if tour is None:
            tour = self.tour

        improvement = True
        iteration = 0
        while improvement:
            improvement = False
            for i in range(1, self.n - 2):
                for k in range(i + 1, self.n):
                    iteration += 1
                    if k - i == 1:
                        continue  # Changes nothing, skip
                    new_tour = self.two_opt_swap(tour, i, k)
                    if self.total_distance(new_tour) < self.total_distance(tour):
                        tour = new_tour
                        improvement = True
                        print(f"Iteration {iteration}: Improved total distance to {self.total_distance(tour):.2f}")

        self.tour = tour

    def solve(self):
        self.nearest_neighbor()
        self.two_opt()
        # Connect the last city back to the starting city to form a closed tour
        self.tour.append(self.tour[0])

# Parse the TSP dataset and extract coordinates
def parse_tsp_dataset(data):
    coordinates = []
    pattern = re.compile(r'(\d+)\s+([\d.]+)\s+([\d.]+)')

    in_node_coord_section = False
    for line in data.split('\n'):
        if line.startswith("NODE_COORD_SECTION"):
            in_node_coord_section = True
            continue
        if line.startswith("EOF"):
            break
        if in_node_coord_section:
            match = pattern.match(line)
            if match:
                coordinates.append((float(match.group(2)), float(match.group(3))))

    return coordinates

# Load the TSP dataset from a file
def load_tsp_file(file_path):
    with open(file_path, 'r') as file:
        tsp_data = file.read()
    return tsp_data

# Specify the path to your TSP file
tsp_file_path = "ch150.tsp"

# Load the TSP dataset from the file
tsp_data = load_tsp_file(tsp_file_path)

# Parse the dataset and extract coordinates
city_coordinates = parse_tsp_dataset(tsp_data)

# Store total distances
total_distances = []

# Rerun TSP solving process 5 times
for i in range(5):
    # Create TSPSolver instance and solve
    solver = TSPSolver(city_coordinates)
    solver.solve()

    # Calculate total distance and add to list
    total_distance = solver.total_distance()
    total_distances.append(total_distance)

    # Plot the solution
    plt.figure()
    plt.scatter(solver.points[:, 0], solver.points[:, 1])
    tour_points = np.array([solver.points[i] for i in solver.tour])
    plt.plot(tour_points[:, 0], tour_points[:, 1], 'r-')
    plt.title(f'TSP Solution {i+1} (Total Distance: {total_distance:.2f})')
    plt.show()

# Calculate and print average tour length
average_tour_length = np.mean(total_distances)
print("Average Tour Length:", average_tour_length)
# Out:
# Iteration 269: Improved total distance to 7238.82
# Iteration 1024: Improved total distance to 7160.92
# Iteration 4592: Improved total distance to 7137.07
# Iteration 6250: Improved total distance to 7134.38
# Iteration 6258: Improved total distance to 7114.78
# Iteration 7183: Improved total distance to 7082.85
# Iteration 8657: Improved total distance to 7065.69
# Iteration 9137: Improved total distance to 7052.25
# Iteration 10082: Improved total distance to 7036.56
# Iteration 11192: Improved total distance to 6891.27
# Iteration 11235: Improved total distance to 6873.54
# Iteration 11382: Improved total distance to 6848.75
# Iteration 11631: Improved total distance to 6839.61
# Iteration 11917: Improved total distance to 6831.10
# Iteration 16494: Improved total distance to 6826.05
# Iteration 18567: Improved total distance to 6815.97
# Iteration 26982: Improved total distance to 6804.32
# Iteration 27086: Improved total distance to 6779.43
# Iteration 27724: Improved total distance to 6757.98
# Iteration 28028: Improved total distance to 6757.96
# Iteration 37892: Improved total distance to 6743.54
# Iteration 48915: Improved total distance to 6714.34
# Iteration 1590: Improved total distance to 7299.17
# Iteration 1712: Improved total distance to 7283.48
# Iteration 5921: Improved total distance to 7279.85
# Iteration 7952: Improved total distance to 7255.99
# Iteration 7979: Improved total distance to 7251.66
# Iteration 8550: Improved total distance to 7245.59
# Iteration 8751: Improved total distance to 7230.93
# Iteration 10384: Improved total distance to 7224.27
# Iteration 10518: Improved total distance to 7196.20
# Iteration 10714: Improved total distance to 7175.34
# Iteration 10759: Improved total distance to 7097.44
# Iteration 10783: Improved total distance to 7084.40
# Iteration 10909: Improved total distance to 7077.23
# Iteration 16934: Improved total distance to 7050.82
# Iteration 17036: Improved total distance to 7043.33
# Iteration 17037: Improved total distance to 7035.37
# Iteration 17234: Improved total distance to 6985.34
# Iteration 19365: Improved total distance to 6971.21
# Iteration 20400: Improved total distance to 6970.82
# Iteration 20401: Improved total distance to 6931.91
# Iteration 20457: Improved total distance to 6908.21
# Iteration 2265: Improved total distance to 7100.51
# Iteration 2382: Improved total distance to 7084.82
# Iteration 7012: Improved total distance to 7083.41
# Iteration 7160: Improved total distance to 7058.49
# Iteration 7162: Improved total distance to 7039.60
# Iteration 7163: Improved total distance to 7019.55
# Iteration 7947: Improved total distance to 7015.76
# Iteration 8327: Improved total distance to 7000.44
# Iteration 9209: Improved total distance to 6930.25
# Iteration 9754: Improved total distance to 6914.03
# Iteration 10682: Improved total distance to 6890.18
# Iteration 10963: Improved total distance to 6887.48
# Iteration 443: Improved total distance to 7176.59
# Iteration 2825: Improved total distance to 7123.81
# Iteration 2931: Improved total distance to 7071.78
# Iteration 3299: Improved total distance to 7006.60
# Iteration 7028: Improved total distance to 6982.74
# Iteration 8476: Improved total distance to 6932.97
# Iteration 8979: Improved total distance to 6925.40
# Iteration 10467: Improved total distance to 6914.06
# Iteration 10566: Improved total distance to 6875.89
# Iteration 10973: Improved total distance to 6862.46
# Iteration 18898: Improved total distance to 6846.23
# Iteration 21492: Improved total distance to 6842.39
# Iteration 29919: Improved total distance to 6826.54
# Iteration 3253: Improved total distance to 7386.69
# Iteration 3545: Improved total distance to 7383.99
# Iteration 4813: Improved total distance to 7382.69
# Iteration 4923: Improved total distance to 7358.01
# Iteration 5250: Improved total distance to 7308.49
# Iteration 8414: Improved total distance to 7240.62
# Iteration 9258: Improved total distance to 7224.93
# Iteration 9685: Improved total distance to 7207.17
# Iteration 10370: Improved total distance to 7200.01
# Iteration 10392: Improved total distance to 7065.43
# Iteration 10398: Improved total distance to 7051.99
# Iteration 10703: Improved total distance to 7037.06
# Iteration 10977: Improved total distance to 7018.89
# Iteration 10994: Improved total distance to 6976.32
# Iteration 20513: Improved total distance to 6968.50
# Iteration 21405: Improved total distance to 6905.59
# Iteration 21407: Improved total distance to 6880.07
# Iteration 21442: Improved total distance to 6853.92
# Iteration 32448: Improved total distance to 6838.40
# Average Tour Length: 6834.996164162253

# %% [markdown]
# ch150_NNHwith3OPT

# %%
import re
import numpy as np
import matplotlib.pyplot as plt
import random

class TSPSolver:
    def __init__(self, points):
        self.points = np.array(points)
        self.n = len(points)
        self.tour = None

    def nearest_neighbor(self, start=None):
        if start is None:
            start = np.random.randint(0, self.n)
        unvisited = set(range(self.n))
        unvisited.remove(start)
        tour = [start]

        while unvisited:
            current_city = tour[-1]
            nearest_city = min(unvisited, key=lambda city: np.linalg.norm(self.points[current_city] - self.points[city]))
            tour.append(nearest_city)
            unvisited.remove(nearest_city)

        self.tour = tour

    def total_distance(self, tour=None):
        if tour is None:
            tour = self.tour
        return sum(np.linalg.norm(self.points[tour[i]] - self.points[tour[i + 1]]) for i in range(self.n - 1))

    def three_opt_swap(self, tour, i, j, k):
        new_tour = tour[:i] + tour[j:k+1][::-1] + tour[i:j] + tour[k+1:]
        return new_tour

    def three_opt(self, tour=None):
        if tour is None:
            tour = self.tour

        improvement = True
        iteration = 0
        while improvement:
            improvement = False
            for i in range(self.n - 4):
                for j in range(i + 2, self.n - 2):
                    for k in range(j + 2, self.n):
                        iteration += 1
                        if random.random() < 0.1:  # Adjust this probability as needed
                            new_tour = self.three_opt_swap(tour, i, j, k)
                            if self.total_distance(new_tour) < self.total_distance(tour):
                                tour = new_tour
                                improvement = True
                                print(f"Iteration {iteration}: Improved total distance to {self.total_distance(tour):.2f}")

        self.tour = tour

    def solve(self):
        self.nearest_neighbor()
        self.three_opt()
        # Connect the last city back to the starting city to form a closed tour
        self.tour.append(self.tour[0])

# Parse the TSP dataset and extract coordinates
def parse_tsp_dataset(data):
    coordinates = []
    pattern = re.compile(r'(\d+)\s+([\d.]+)\s+([\d.]+)')

    in_node_coord_section = False
    for line in data.split('\n'):
        if line.startswith("NODE_COORD_SECTION"):
            in_node_coord_section = True
            continue
        if line.startswith("EOF"):
            break
        if in_node_coord_section:
            match = pattern.match(line)
            if match:
                coordinates.append((float(match.group(2)), float(match.group(3))))

    return coordinates

# Load the TSP dataset from a file
def load_tsp_file(file_path):
    with open(file_path, 'r') as file:
        tsp_data = file.read()
    return tsp_data

# Specify the path to your TSP file
tsp_file_path = "ch150.tsp"

# Load the TSP dataset from the file
tsp_data = load_tsp_file(tsp_file_path)

# Parse the dataset and extract coordinates
city_coordinates = parse_tsp_dataset(tsp_data)

# Store total distances for three runs
total_distances = []

# Run the solver three times
for _ in range(3):
    solver = TSPSolver(city_coordinates)
    solver.solve()
    total_distance = solver.total_distance()
    total_distances.append(total_distance)

    # Plot the solution for each run
    plt.scatter(solver.points[:, 0], solver.points[:, 1])
    tour_points = np.array([solver.points[i] for i in solver.tour])
    plt.plot(tour_points[:, 0], tour_points[:, 1], 'r-')
    plt.title(f'TSP Solution using Nearest Neighbor with 3-opt (Total Distance: {total_distance:.2f})')
    plt.show()

# Calculate and print the average total distance
average_distance = sum(total_distances) / len(total_distances)
print(f"Average Tour Length: {average_distance:.2f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 103
#     101 for _ in range(1):
#     102     solver = TSPSolver(city_coordinates)
# --> 103     solver.solve()
#     104     total_distance = solver.total_distance()
#     105     total_distances.append(total_distance)
#
# Cell In[3], line 58, in TSPSolver.solve(self)
#      57 def solve(self):
# ---> 58     self.nearest_neighbor()
#      59     self.three_opt()
#      60     # Connect the last city back to the starting city to form a closed tour
#
# Cell In[3], line 14, in TSPSolver.nearest_neighbor(self, start)
#      12 def nearest_neighbor(self, start=None):
#      13     if start is None:
# ---> 14         start = np.random.randint(0, self.n)
#      15     unvisited = set(range(self.n))
#      16     unvisited.remove(start)
#
# File mtrand.pyx:781, in numpy.random.mtrand.RandomState.randint()
#
# File _bounded_integers.pyx:1334, in numpy.random._bounded_integers._rand_int64()
#
# ValueError: high <= 0
